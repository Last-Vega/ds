# %%
# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第3位まで表示
# %precision 3
# Out:
# '%.3f'

# %%
hier_df = DataFrame(
    np.arange(9).reshape((3,3)),
    index = [
        ["a", "a", "b"],
        [1, 2, 2]
    ],
    columns = [
        ["Osaka", "Tokyo", "Osaka"],
        ["Blue"," Red", "Red"]
    ]
)

hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
# 3列3行のデータを作成し、インデックスとカラムを設定
hier_df= DataFrame(
    np.arange(9).reshape((3,3)),
    index = [
        ['a','a','b'],
        [1,2,2]
    ], 
    columns = [
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
# indexに名前を付ける
hier_df.index.names =['key1','key2']
# カラムに名前を付ける
hier_df.columns.names =['city','color']
hier_df
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5
# b    2        6     7     8

# %%
hier_df["Osaka"]
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
#      2        3    5
# b    2        6    8

# %%
# 階層ごとの要約統計量：行合計
hier_df.sum(level = 'key2', axis = 0)
# Out:
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1         0     1     2
# 2         9    11    13

# %%
# 列合計
hier_df.sum(level = 'color', axis = 1)
# Out:
# color      Blue   Red  Red
# key1 key2
# a    1        0     1    2
#      2        3     4    5
# b    2        6     7    8

# %%
hier_df1 = DataFrame(
    np.arange(12).reshape((3,4)),
    index = [['c','d','d'],[1,2,1]],
    columns = [
        ['Kyoto','Nagoya','Hokkaido','Kyoto'],
        ['Yellow','Yellow','Red','Blue']
    ]
)

hier_df1.index.names = ['key1','key2']
hier_df1.columns.names = ['city','color']
hier_df1
# Out:
# city       Kyoto Nagoya Hokkaido Kyoto
# color     Yellow Yellow      Red  Blue
# key1 key2
# c    1         0      1        2     3
# d    2         4      5        6     7
#      1         8      9       10    11

# %%
hier_df1["Kyoto"]
# Out:
# color      Yellow  Blue
# key1 key2
# c    1          0     3
# d    2          4     7
#      1          8    11

# %%
hier_df1.mean(level = 'city', axis = 1)
# Out:
# city       Kyoto  Nagoya  Hokkaido
# key1 key2
# c    1       1.5     1.0       2.0
# d    2       5.5     5.0       6.0
#      1       9.5     9.0      10.0

# %%
hier_df1.sum(level='key2')
# Out:
# city   Kyoto Nagoya Hokkaido Kyoto
# color Yellow Yellow      Red  Blue
# key2
# 1          8     10       12    14
# 2          4      5        6     7

# %%
# データ1の準備
data1 = {
    'id': ['100', '101', '102', '103', '104', '106', '108', '110', '111',' 113'],
    'city': ['Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo', 'Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo'],
    'birth_year': [1990, 1989, 1992, 1997, 1982, 1991, 1988, 1990, 1995, 1981],
    'name': ['Hiroshi', 'Akiko', 'Yuki', 'Satoru', 'Steeve', 'Mituru', 'Aoi', 'Tarou', 'Suguru','Mitsuo']
}
df1 = DataFrame(data1)
df1
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo

# %%
# データ2の準備
data2 = {
    'id': ['100', '101', '102', '105', '107'],
    'math': [50, 43, 33, 76, 98],
    'english': [90, 30, 20, 50, 30],
    'sex': ['M','F','F','M','M'], 
    'index_num': [0, 1, 2, 3, 4]
}
df2 = DataFrame(data2)
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
# データのマージ（内部結合。キーは自動的に認識されるが、onで明示的に指定可能）
print('・結合テーブル')
pd.merge(df1, df2, on = 'id')
# Out:
# ・結合テーブル
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
# データのマージ（全結合）
pd.merge(df1, df2, how = 'outer')
# Out:
#       id      city  birth_year     name  math  english  sex  index_num
# 0    100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1    101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2    102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3    103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4    104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5    106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6    108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7    110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8    111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9    113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 10   105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 11   107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
# index によるマージ
pd.merge(df1, df2, left_index = True, right_on = 'index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
# データのマージ（left）
pd.merge(df1, df2, how = 'left')
# Out:
#      id      city  birth_year     name  math  english  sex  index_num
# 0   100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
# データ3の準備
data3 = {
    'id': ['117', '118', '119', '120', '125'],
    'city': ['Chiba', 'Kanagawa', 'Tokyo', 'Fukuoka', 'Okinawa'],
    'birth_year': [1990, 1989, 1992, 1997, 1982],
    'name': ['Suguru', 'Kouichi', 'Satochi', 'Yukie', 'Akari']
}
df3 = DataFrame(data3)
df3
# Out:
#     id      city  birth_year     name
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
# concat 縦結合
concat_data = pd.concat([df1,df3])
concat_data
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo
# 0   117     Chiba        1990   Suguru
# 1   118  Kanagawa        1989  Kouichi
# 2   119     Tokyo        1992  Satochi
# 3   120   Fukuoka        1997    Yukie
# 4   125   Okinawa        1982    Akari

# %%
# hier_dfを用意
hier_df= DataFrame(
    np.arange(9).reshape((3, 3)),
    index = [
        ['a', 'a', 'b'],
        [1, 2, 2]
    ],
    columns = [
        ['Osaka', 'Tokyo', 'Osaka'],
        ['Blue','Red','Red']
    ]
)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
#　ピボット操作で「Blue、Red」の列を行に変更
hier_df.stack()
# Out:
#           Osaka  Tokyo
# a 1 Blue      0    NaN
#     Red       2    1.0
#   2 Blue      3    NaN
#     Red       5    4.0
# b 2 Blue      6    NaN
#     Red       8    7.0

# %%
#　重複があるデータ
dupli_data = DataFrame({
        'col1': [1, 1, 2, 3, 4, 4, 6, 6],
        'col2': ['a', 'b', 'b', 'b', 'c', 'c', 'b', 'b']
})
print('・元のデータ')
dupli_data
# Out:
# ・元のデータ
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
#　重複判定
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
#　重複削除
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
# 参照データ
city_map ={
    'Tokyo': 'Kanto',
    'Hokkaido': 'Hokkaido',
    'Osaka': 'Kansai',
    'Kyoto':'Kansai'
}
city_map
# Out:
# {'Tokyo': 'Kanto',
#  'Hokkaido': 'Hokkaido',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai'}

# %%
#　参照データを結合
# もし対応するデータがなかったら、NaNになる。
df1['region'] = df1['city'].map(city_map)
df1
# Out:
#      id      city  birth_year     name    region
# 0   100     Tokyo        1990  Hiroshi     Kanto
# 1   101     Osaka        1989    Akiko    Kansai
# 2   102     Kyoto        1992     Yuki    Kansai
# 3   103  Hokkaido        1997   Satoru  Hokkaido
# 4   104     Tokyo        1982   Steeve     Kanto
# 5   106     Tokyo        1991   Mituru     Kanto
# 6   108     Osaka        1988      Aoi    Kansai
# 7   110     Kyoto        1990    Tarou    Kansai
# 8   111  Hokkaido        1995   Suguru  Hokkaido
# 9   113     Tokyo        1981   Mitsuo     Kanto

# %%
#　birth_year の上3つの数字・文字を取り出す
df1['up_two_num'] = df1['birth_year'].map(lambda x: str(x)[0:3])
df1
# Out:
#      id      city  birth_year     name    region up_two_num
# 0   100     Tokyo        1990  Hiroshi     Kanto        199
# 1   101     Osaka        1989    Akiko    Kansai        198
# 2   102     Kyoto        1992     Yuki    Kansai        199
# 3   103  Hokkaido        1997   Satoru  Hokkaido        199
# 4   104     Tokyo        1982   Steeve     Kanto        198
# 5   106     Tokyo        1991   Mituru     Kanto        199
# 6   108     Osaka        1988      Aoi    Kansai        198
# 7   110     Kyoto        1990    Tarou    Kansai        199
# 8   111  Hokkaido        1995   Suguru  Hokkaido        199
# 9   113     Tokyo        1981   Mitsuo     Kanto        198

# %%
#　分割の粒度
birth_year_bins = [1980, 1985, 1990, 1995, 2000]

# ビン分割の実施
birth_year_cut_data = pd.cut(df1.birth_year, birth_year_bins)
birth_year_cut_data
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: birth_year, dtype: category
# Categories (4, interval[int64]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
# 集計結果
pd.value_counts(birth_year_cut_data)
# Out:
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: birth_year, dtype: int64

# %%
# 名前をつける
group_names = ['early1980s', 'late1980s', 'early1990s', 'late1990s']
birth_year_cut_data = pd.cut(df1.birth_year, birth_year_bins, labels = group_names)
pd.value_counts(birth_year_cut_data)
# Out:
# late1980s     4
# early1990s    3
# early1980s    2
# late1990s     1
# Name: birth_year, dtype: int64

# %%
# 数字で分割数指定可能。ここでは2つに分割
pd.cut(df1.birth_year, 2)
# Out:
# 0      (1989.0, 1997.0]
# 1    (1980.984, 1989.0]
# 2      (1989.0, 1997.0]
# 3      (1989.0, 1997.0]
# 4    (1980.984, 1989.0]
# 5      (1989.0, 1997.0]
# 6    (1980.984, 1989.0]
# 7      (1989.0, 1997.0]
# 8      (1989.0, 1997.0]
# 9    (1980.984, 1989.0]
# Name: birth_year, dtype: category
# Categories (2, interval[float64]): [(1980.984, 1989.0] < (1989.0, 1997.0]]

# %%
pd.value_counts(pd.qcut(df1.birth_year, 2))
# Out:
# (1980.999, 1990.0]    6
# (1990.0, 1997.0]      4
# Name: birth_year, dtype: int64

# %%
student_data_math = pd.read_csv('student-mat.csv', sep=';')

# %%
student_data_math['double_age'] = student_data_math['age'].map(lambda x: x*2)

# %%
student_data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#      ...     freetime goout  Dalc  Walc  health absences  G1  G2  G3  \
# 0    ...            3     4     1     1       3        6   5   6   6
# 1    ...            3     3     1     1       3        4   5   5   6
# 2    ...            3     2     2     3       3       10   7   8  10
# 3    ...            2     2     1     1       5        2  15  14  15
# 4    ...            3     2     1     2       5        4   6  10  10
#
#   double_age
# 0         36
# 1         34
# 2         30
# 3         30
# 4         32
#
# [5 rows x 34 columns]

# %%
absence_bins = [0,1,5,100]
absences_cut_data = pd.cut(student_data_math.absences, absence_bins, right=False)
absences_cut_data
# Out:
# 0      [5, 100)
# 1        [1, 5)
# 2      [5, 100)
# 3        [1, 5)
# 4        [1, 5)
# 5      [5, 100)
# 6        [0, 1)
# 7      [5, 100)
# 8        [0, 1)
# 9        [0, 1)
# 10       [0, 1)
# 11       [1, 5)
# 12       [1, 5)
# 13       [1, 5)
# 14       [0, 1)
# 15       [1, 5)
# 16     [5, 100)
# 17       [1, 5)
# 18     [5, 100)
# 19       [1, 5)
# 20       [0, 1)
# 21       [0, 1)
# 22       [1, 5)
# 23       [0, 1)
# 24       [1, 5)
# 25     [5, 100)
# 26       [1, 5)
# 27       [1, 5)
# 28       [1, 5)
# 29     [5, 100)
#          ...
# 365      [1, 5)
# 366      [0, 1)
# 367      [0, 1)
# 368      [0, 1)
# 369    [5, 100)
# 370      [1, 5)
# 371      [1, 5)
# 372    [5, 100)
# 373    [5, 100)
# 374      [0, 1)
# 375      [1, 5)
# 376      [1, 5)
# 377      [1, 5)
# 378      [0, 1)
# 379    [5, 100)
# 380      [1, 5)
# 381    [5, 100)
# 382      [1, 5)
# 383      [0, 1)
# 384    [5, 100)
# 385      [1, 5)
# 386    [5, 100)
# 387      [0, 1)
# 388      [0, 1)
# 389      [0, 1)
# 390    [5, 100)
# 391      [1, 5)
# 392      [1, 5)
# 393      [0, 1)
# 394    [5, 100)
# Name: absences, Length: 395, dtype: category
# Categories (3, interval[int64]): [[0, 1) < [1, 5) < [5, 100)]

# %%
pd.value_counts(absences_cut_data)
# Out:
# [5, 100)    151
# [1, 5)      129
# [0, 1)      115
# Name: absences, dtype: int64

# %%
absences_qcut_data = pd.qcut(student_data_math.absences,3)
pd.value_counts(absences_qcut_data)
# Out:
# (-0.001, 2.0]    183
# (6.0, 75.0]      115
# (2.0, 6.0]        97
# Name: absences, dtype: int64

# %%
df1.groupby('city').size()
# Out:
# city
# Hokkaido    2
# Kyoto       2
# Osaka       2
# Tokyo       4
# dtype: int64

# %%
df1.groupby('city')['birth_year'].mean()
# Out:
# city
# Hokkaido    1996.0
# Kyoto       1991.0
# Osaka       1988.5
# Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region', 'city'])['birth_year'].mean()
# Out:
# region    city
# Hokkaido  Hokkaido    1996.0
# Kansai    Kyoto       1991.0
#           Osaka       1988.5
# Kanto     Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region', 'city'], as_index = False)['birth_year'].mean()
# Out:
#      region      city  birth_year
# 0  Hokkaido  Hokkaido      1996.0
# 1    Kansai     Kyoto      1991.0
# 2    Kansai     Osaka      1988.5
# 3     Kanto     Tokyo      1986.0

# %%
for group, subdf in df1.groupby('region'):
    print('==========================================================')
    print('Region Name:{0}'.format(group))
    print(subdf)
# Out:
# ==========================================================
# Region Name:Hokkaido
#     id      city  birth_year    name    region up_two_num
# 3  103  Hokkaido        1997  Satoru  Hokkaido        199
# 8  111  Hokkaido        1995  Suguru  Hokkaido        199
# ==========================================================
# Region Name:Kansai
#     id   city  birth_year   name  region up_two_num
# 1  101  Osaka        1989  Akiko  Kansai        198
# 2  102  Kyoto        1992   Yuki  Kansai        199
# 6  108  Osaka        1988    Aoi  Kansai        198
# 7  110  Kyoto        1990  Tarou  Kansai        199
# ==========================================================
# Region Name:Kanto
#      id   city  birth_year     name region up_two_num
# 0   100  Tokyo        1990  Hiroshi  Kanto        199
# 4   104  Tokyo        1982   Steeve  Kanto        198
# 5   106  Tokyo        1991   Mituru  Kanto        199
# 9   113  Tokyo        1981   Mitsuo  Kanto        198

# %%
functions = ['count','mean','max','min']
grouped_student_math_data1 = student_data_math.groupby(['sex','address'])
grouped_student_math_data1['age','G1'].agg(functions)
# Out:
#               age                       G1
#             count       mean max min count       mean max min
# sex address
# F   R          44  16.977273  19  15    44  10.295455  19   6
#     U         164  16.664634  20  15   164  10.707317  18   4
# M   R          44  17.113636  21  15    44  10.659091  18   3
#     U         143  16.517483  22  15   143  11.405594  19   5

# %%
student_data_math.groupby('school')['G1'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: G1, dtype: float64

# %%
student_data_math.groupby(["school", "sex"])['G1', 'G2', 'G3'].mean()
# Out:
#                    G1         G2         G3
# school sex
# GP     F    10.579235  10.398907   9.972678
#        M    11.337349  11.204819  11.060241
# MS     F    10.920000  10.320000   9.920000
#        M    10.380952  10.047619   9.761905

# %%
function = ["max", "min"]
student_data_math.groupby(["school", "sex"])['G1', 'G2', 'G3'].agg(function)
# Out:
#             G1      G2      G3
#            max min max min max min
# school sex
# GP     F    18   4  18   0  19   0
#        M    19   3  19   0  20   0
# MS     F    19   6  18   5  19   0
#        M    15   6  16   5  16   0

# %%
function = ["max", "min"]
grouped = student_data_math.groupby(["sex", "school"])
grouped['G1', 'G2', 'G3'].agg(function)
# Out:
#             G1      G2      G3
#            max min max min max min
# sex school
# F   GP      18   4  18   0  19   0
#     MS      19   6  18   5  19   0
# M   GP      19   3  19   0  20   0
#     MS      15   6  16   5  16   0

# %%
# データの準備
import numpy as np
from numpy import nan as NA
import pandas as pd


df = pd.DataFrame(np.random.rand(10, 4))

# NAにする
df.iloc[1,0] = NA
df.iloc[2:3,2] = NA
df.iloc[5:,3] = NA

# %%
df
# Out:
#           0         1         2         3
# 0  0.171892  0.289559  0.832072  0.554576
# 1       NaN  0.065527  0.930612  0.336886
# 2  0.069669  0.500228       NaN  0.904556
# 3  0.534927  0.124446  0.732447  0.449293
# 4  0.413629  0.552311  0.972569  0.738592
# 5  0.413566  0.115632  0.572818       NaN
# 6  0.649542  0.152268  0.580546       NaN
# 7  0.544980  0.668750  0.792459       NaN
# 8  0.542599  0.052708  0.795962       NaN
# 9  0.181560  0.026675  0.603940       NaN

# %%
df.dropna()
# Out:
#           0         1         2         3
# 0  0.171892  0.289559  0.832072  0.554576
# 3  0.534927  0.124446  0.732447  0.449293
# 4  0.413629  0.552311  0.972569  0.738592

# %%
df[[0,1]].dropna()
# Out:
#           0         1
# 0  0.171892  0.289559
# 2  0.069669  0.500228
# 3  0.534927  0.124446
# 4  0.413629  0.552311
# 5  0.413566  0.115632
# 6  0.649542  0.152268
# 7  0.544980  0.668750
# 8  0.542599  0.052708
# 9  0.181560  0.026675

# %%
df.fillna(0)
# Out:
#           0         1         2         3
# 0  0.171892  0.289559  0.832072  0.554576
# 1  0.000000  0.065527  0.930612  0.336886
# 2  0.069669  0.500228  0.000000  0.904556
# 3  0.534927  0.124446  0.732447  0.449293
# 4  0.413629  0.552311  0.972569  0.738592
# 5  0.413566  0.115632  0.572818  0.000000
# 6  0.649542  0.152268  0.580546  0.000000
# 7  0.544980  0.668750  0.792459  0.000000
# 8  0.542599  0.052708  0.795962  0.000000
# 9  0.181560  0.026675  0.603940  0.000000

# %%
df.fillna(method = 'ffill')
# Out:
#           0         1         2         3
# 0  0.171892  0.289559  0.832072  0.554576
# 1  0.171892  0.065527  0.930612  0.336886
# 2  0.069669  0.500228  0.930612  0.904556
# 3  0.534927  0.124446  0.732447  0.449293
# 4  0.413629  0.552311  0.972569  0.738592
# 5  0.413566  0.115632  0.572818  0.738592
# 6  0.649542  0.152268  0.580546  0.738592
# 7  0.544980  0.668750  0.792459  0.738592
# 8  0.542599  0.052708  0.795962  0.738592
# 9  0.181560  0.026675  0.603940  0.738592

# %%
import pandas_datareader.data as pdr

# %%
start_date = '2001/1/2'
end_date = '2016/12/30'

fx_jpusdata = pdr.DataReader('DEXJPUS', 'fred', start_date, end_date)

# %%
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
fx_jpusdata['2016-04']
# Out:
#             DEXJPUS
# DATE
# 2016-04-01   112.06
# 2016-04-04   111.18
# 2016-04-05   110.26
# 2016-04-06   109.63
# 2016-04-07   107.98
# 2016-04-08   108.36
# 2016-04-11   107.96
# 2016-04-12   108.54
# 2016-04-13   109.21
# 2016-04-14   109.20
# 2016-04-15   108.76
# 2016-04-18   108.85
# 2016-04-19   109.16
# 2016-04-20   109.51
# 2016-04-21   109.41
# 2016-04-22   111.50
# 2016-04-25   111.08
# 2016-04-26   111.23
# 2016-04-27   111.26
# 2016-04-28   108.55
# 2016-04-29   106.90

# %%
fx_jpusdata.resample('M').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-31   116.39
# 2001-02-28   117.28
# 2001-03-31   125.54
# 2001-04-30   123.57
# 2001-05-31   118.88

# %%
fx_jpusdata.resample('D').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06      NaN

# %%
fx_jpusdata.resample('D').ffill().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06   116.19

# %%
fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
fx_jpusdata_ratio = fx_jpusdata / fx_jpusdata.shift(1)
fx_jpusdata_ratio.head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03  0.995903
# 2001-01-04  1.010590
# 2001-01-05  1.006235
# 2001-01-08  0.998107

# %%
fx_jpusdata.resample('Y').mean().head()
# Out:
#                DEXJPUS
# DATE
# 2001-12-31  121.568040
# 2002-12-31  125.220438
# 2003-12-31  115.938685
# 2004-12-31  108.150830
# 2005-12-31  110.106932

# %%
fx_jpusdata.rolling(3).mean().head()
# Out:
#                DEXJPUS
# DATE
# 2001-01-02         NaN
# 2001-01-03         NaN
# 2001-01-04  114.820000
# 2001-01-05  115.306667
# 2001-01-08  115.876667

# %%
fx_jpusdata.rolling(3).std().head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03       NaN
# 2001-01-04  0.610000
# 2001-01-05  0.975312
# 2001-01-08  0.368963

# %%
fx_jpusdata.rolling(20).mean().dropna().head()
# Out:
#              DEXJPUS
# DATE
# 2001-02-12  116.6910
# 2001-02-13  116.6920
# 2001-02-14  116.6070
# 2001-02-15  116.5015
# 2001-02-16  116.4130
